# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatch
import seaborn as sns
import numpy as np
import pandas as pd

# %%
base_url = "../data/covid/"
bird = base_url + "birds.csv"

# %%
birds=pd.read_csv(bird)

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
birds.plot()
# Out:
# <Axes: >

# %%
sns.set(style="darkgrid")

sns.barplot(

    x="Family",

    y="Genus",        

    data=birds,

    color="cyan"

)

plt.figure(figsize=(18,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 15
#       1 sns.set(style="darkgrid")
#       3 sns.barplot(
#       4
#       5     x="Family",
#    (...)
#      12
#      13 )
# ---> 15 plt.figure(figsize=(18,8))
#
# TypeError: 'module' object is not callable

# %%
sns.histplot(data=birds, x='Family',kde=True)
# Out:
# <Axes: xlabel='Family', ylabel='Count'>

# %%
sns.displot(birds["Family"])

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
my_plot=plt.barh(
         y=birds.ScientificName,
         width=birds.Name,
         color=birds.TABLEAU_COLORS,
         edgecolor='black',
         linewidth=3
         
         )
plt.bar_label(container=my_plot, padding=-10)
# Out:
# [Text(-10, 0, '0'),
#  Text(-10, 0, '1'),
#  Text(-10, 0, '2'),
#  Text(-10, 0, '3'),
#  Text(-10, 0, '4'),
#  Text(-10, 0, '5'),
#  Text(-10, 0, '6'),
#  Text(-10, 0, '7'),
#  Text(-10, 0, '8'),
#  Text(-10, 0, '9'),
#  Text(-10, 0, '10'),
#  Text(-10, 0, '11'),
#  Text(-10, 0, '12'),
#  Text(-10, 0, '13'),
#  Text(-10, 0, '14'),
#  Text(-10, 0, '15'),
#  Text(-10, 0, '16'),
#  Text(-10, 0, '17'),
#  Text(-10, 0, '18'),
#  Text(-10, 0, '19'),
#  Text(-10, 0, '20'),
#  Text(-10, 0, '21'),
#  Text(-10, 0, '22'),
#  Text(-10, 0, '23'),
#  Text(-10, 0, '24'),
#  Text(-10, 0, '25'),
#  Text(-10, 0, '26'),
#  Text(-10, 0, '27'),
#  Text(-10, 0, '28'),
#  Text(-10, 0, '29'),
#  Text(-10, 0, '30'),
#  Text(-10, 0, '31'),
#  Text(-10, 0, '32'),
#  Text(-10, 0, '33'),
#  Text(-10, 0, '34'),
#  Text(-10, 0, '35'),
#  Text(-10, 0, '36'),
#  Text(-10, 0, '37'),
#  Text(-10, 0, '38'),
#  Text(-10, 0, '39'),
#  Text(-10, 0, '40'),
#  Text(-10, 0, '41'),
#  Text(-10, 0, '42'),
# ...

# %%
g = sns.FacetGrid(birds.head(),  col="Category", height=4, aspect=.5)

g.map(sns.barplot, "Genus", "MinBodyMass", order=["Dendrocygna", "Anser"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 g = sns.FacetGrid(birds.head(),  col="Category", height=4, aspect=.5)
#       3 g.map(sns.barplot, "Genus", "MinBodyMass", order=["Dendrocygna", "Anser"])
#
# AttributeError: 'ellipsis' object has no attribute 'head'

# %%
birds.head(100)
# Out:
#                             Name           ScientificName  \
# 0   Black-bellied whistling-duck   Dendrocygna autumnalis
# 1         Fulvous whistling-duck      Dendrocygna bicolor
# 2                     Snow goose       Anser caerulescens
# 3                   Ross's goose             Anser rossii
# 4    Greater white-fronted goose          Anser albifrons
# ..                           ...                      ...
# 95            Black-necked stilt     Himantopus mexicanus
# 96               American avocet  Recurvirostra americana
# 97          Black-bellied plover     Pluvialis squatarola
# 98        American golden-plover       Pluvialis dominica
# 99                      Killdeer     Charadrius vociferus
#
#                  Category            Order            Family          Genus  \
# 0   Ducks/Geese/Waterfowl     Anseriformes          Anatidae    Dendrocygna
# 1   Ducks/Geese/Waterfowl     Anseriformes          Anatidae    Dendrocygna
# ...

# %%
total=birds.groupby('Family')['Name'].sum().reset_index()

# %%
total
# Out:
#                Family                                               Name
# 0        Accipitridae  White-tailed kiteSwallow-tailed kiteGolden eag...
# 1           Alaudidae                                        Horned lark
# 2         Alcedinidae                                  Belted kingfisher
# 3             Alcidae  DovekieBlack guillemotLong-billed murreletAnci...
# 4            Anatidae  Black-bellied whistling-duckFulvous whistling-...
# 5            Apodidae                  Chimney swiftWhite-throated swift
# 6            Ardeidae  American bitternLeast bitternGreat blue heronG...
# 7       Bombycillidae                      Bohemian waxwingCedar waxwing
# 8         Calcariidae  Lapland longspurChestnut-collared longspurSmit...
# 9       Caprimulgidae  Common nighthawkCommon poorwillChuck-will's-wi...
# 10       Cardinalidae  Summer tanagerScarlet tanagerWestern tanagerNo...
# 11        Cathartidae                        Black vultureTurkey vulture
# ...

# %%
bar1=sns.barplot(x="Family",y="Genus", data=birds.head(),color='darkblue')

# %%
sns.set(style="darkgrid")

sns.barplot(

    x="Family",

    y="Genus",        

    data=birds.head(70), #İlk 70 veri için

    color="cyan"

)

plt.figure(figsize=(18,8))

# %%
g = sns.FacetGrid(birds.head(), col="Category", height=4, aspect=.5)

g.map(sns.barplot, "Genus", "MinBodyMass", order=["Dendrocygna", "Anser"])

# %%
g = sns.FacetGrid(birds.head(), col="Category", height=4, aspect=.5)

g.map(sns.barplot, "Genus", "MinBodyMass", order=["Dendrocygna", "Anser"])

# %%
sns.barplot(style="darkgrid")
sns.barplot(
    x='Genus',
    y='MinBodyMass',
    data=birds,
    color='cyan'
)
plt.figure(figsize=(12,6))

# %%
sns.regplot(x=birds['MinLength'],y=birds['MaxLength'])
# Out:
# <Axes: xlabel='MinLength', ylabel='MaxLength'>

# %%
sns.regplot(
    x=birds['MinLength'],
    y=birds['MaxLength'],
    marker="o", #Plot'un şeklini değiştirme
    line_kws={
        "color":"red",
        "alpha":0.6,
        "lw":5
    },
    scatter_kws={
        "color":"darkblue",
        "s":12
    }
    )
# Out:
# <Axes: xlabel='MinLength', ylabel='MaxLength'>

# %%
sns.regplot(
    x=birds['MinLength'],
    y=birds['MaxLength'],
    marker="x", #Plot'un şeklini değiştirme
    line_kws={
        "color":"purple",
        "alpha":0.6,
        "lw":5
    },
    scatter_kws={
        "color":"darkblue",
        "s":12
    }
    )
# Out:
# <Axes: xlabel='MinLength', ylabel='MaxLength'>

# %%
sns.regplot(
    x=birds['MinBodyMass'],
    y=birds['MaxBodyMass'],
    marker="o", #Plot'un şeklini değiştirme
    line_kws={
        "color":"pink",
        "alpha":0.6,
        "lw":5
    },
    scatter_kws={
        "color":"darkred",
        "s":12
    }
    )
# Out:
# <Axes: xlabel='MinBodyMass', ylabel='MaxBodyMass'>

# %%
sns.lmplot(
    x='MaxLength', 
    y='MinLength', 
    data=birds,
    hue="Family",
    )
