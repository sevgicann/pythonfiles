# %%
import pandas as pd
import numpy as np

# %%
infected_dataset_url =  "time_series_covid19_confirmed_global.csv"
recovered_dataset_url =  "time_series_covid19_recovered_global.csv"
deaths_dataset_url =  "time_series_covid19_deaths_global.csv"
lookTable_url="UID_ISO_FIPS_LookUp_Table.csv"

# %%
infected_data=pd.read_csv(infected_dataset_url)
recovered_data=pd.read_csv(recovered_dataset_url)
deaths_data=pd.read_csv(deaths_dataset_url)
lookTable=pd.read_csv(lookTable_url)
lookTable.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 3   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
# 4   24   AO  AGO   24.0   NaN    NaN            NaN         Angola -11.20270
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2   1.659600      Algeria  43851043.0
# 3   1.521800      Andorra     77265.0
# 4  17.873900       Angola  32866268.0

# %%
infected_data.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    21.148043   22.538640    2.086466    2.458647    3.537594    5.390977
# std     24.909990   70.466256   27.279200   27.377862   34.083035   47.434934
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.907750  -18.093125    0.000000    0.000000    0.000000    0.000000
# 50%     23.488100   20.972650    0.000000    0.000000    0.000000    0.000000
# 75%     41.143200   77.191525    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        6/6/20  \
# count   266.000000   266.000000   266.000000   266.000000  ...  2.660000e+02
# mean      7.962406    11.003759    20.969925    23.180451  ...  2.594981e+04
# ...

# %%
infected_data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
infected_data.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
infected_data.info
# Out:
# <bound method DataFrame.info of     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
# ...

# %%
infected_data['Province/State'].value_counts() 
# Uniqe değerlerin sayısını döndürecek
# Out:
# Province/State
# Australian Capital Territory    1
# Qinghai                         1
# Reunion                         1
# New Caledonia                   1
# Mayotte                         1
#                                ..
# Guizhou                         1
# Guangxi                         1
# Guangdong                       1
# Gansu                           1
# Saint Pierre and Miquelon       1
# Name: count, Length: 81, dtype: int64

# %%
infected_data[infected_data['Country/Region']=='China']
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 49           Anhui          China  31.8257  117.2264        1        9
# 50         Beijing          China  40.1824  116.4142       14       22
# 51       Chongqing          China  30.0572  107.8740        6        9
# 52          Fujian          China  26.0789  117.9874        1        5
# 53           Gansu          China  37.8099  101.0583        0        2
# 54       Guangdong          China  23.3417  113.4244       26       32
# 55         Guangxi          China  23.8298  108.7881        2        5
# 56         Guizhou          China  26.8154  106.8748        1        3
# 57          Hainan          China  19.1959  109.7453        4        5
# 58           Hebei          China  39.5490  116.1306        1        1
# 59    Heilongjiang          China  47.8620  127.7615        0        2
# 60           Henan          China  33.8820  113.6140        5        5
# ...

# %%
recovered_data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...    1830    1875    2171    2651     3013
# 1        0        0        0  ...     925     938     945     960      980
# 2        0        0        0  ...    6631    6717    6799    6951     7074
# 3        0        0        0  ...     741     744     751     757      759
# 4        0        0        0  ...      24      24      38      38       40
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
infected_data.size
# Out:
# 39900

# %%
infected_data.columns==recovered_data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
all(infected_data.columns==recovered_data.columns)
## Column'lar aynı mı tek birr boolean değerde döndürür
# Out:
# True

# %%
def compare_columns(df1,df2):
    return all(df1.columns==df2.columns)

# %%
print(compare_columns(infected_data,recovered_data))
print(compare_columns(infected_data,deaths_data))
# Out:
# True
# True

# %%
infected_data.shape
# Out:
# (266, 150)

# %%
df_infected=infected_data.groupby('Country/Region').sum()
#Birden fazla aynı ülke varsa birleştirildi

# %%
df_infected.head()
# Out:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  6/6/20  6/7/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   19551   20342
# Albania               0        0        0        0  ...    1232    1246
# Algeria               0        0        0        0  ...   10050   10154
# Andorra               0        0        0        0  ...     852     852
# Angola                0        0        0        0  ...      88      91
#
# ...

# %%
df_infected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, Afghanistan to Zimbabwe
# Columns: 149 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(1)
# memory usage: 220.3+ KB

# %%
df_infected[df_infected['Province/State']!=0]
# Out:
#                                                    Province/State        Lat  \
# Country/Region
# Australia       Australian Capital TerritoryNew South WalesNor...  -255.9695
# Canada          AlbertaBritish ColumbiaGrand PrincessManitobaN...   671.7607
# China           AnhuiBeijingChongqingFujianGansuGuangdongGuang...  1083.3367
# Denmark                                    Faroe IslandsGreenland   189.8634
# France          French GuianaFrench PolynesiaGuadeloupeMayotte...    91.3624
# Netherlands     ArubaCuracaoSint MaartenBonaire, Sint Eustatiu...   107.0417
# United Kingdom  BermudaCayman IslandsChannel IslandsGibraltarI...   270.0299
#
#                      Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Australia       1129.8623        0        0        0        0        4
# Canada         -1237.6289        0        0        0        0        1
# China           3684.4197      548      643      920     1406     2075
# ...

# %%
infected_data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
infected_data[infected_data['Country/Region']=='China']['1/22/20'].sum()
# Out:
# 548

# %%
df_infected=recovered_data.groupby('Country/Region').sum()
df_deaths=deaths_data.groupby('Country/Region').sum()

# %%
infected_data["Country/Region"]
# Out:
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                    Andorra
# 4                     Angola
#                ...
# 261    Sao Tome and Principe
# 262                    Yemen
# 263                  Comoros
# 264               Tajikistan
# 265                  Lesotho
# Name: Country/Region, Length: 266, dtype: object

# %%
infected_data["Country/Region"].to_frame()
# Out:
#             Country/Region
# 0              Afghanistan
# 1                  Albania
# 2                  Algeria
# 3                  Andorra
# 4                   Angola
# ..                     ...
# 261  Sao Tome and Principe
# 262                  Yemen
# 263                Comoros
# 264             Tajikistan
# 265                Lesotho
#
# [266 rows x 1 columns]

# %%
infected_data[["Country/Region","Lat"]]
# Out:
#             Country/Region        Lat
# 0              Afghanistan  33.000000
# 1                  Albania  41.153300
# 2                  Algeria  28.033900
# 3                  Andorra  42.506300
# 4                   Angola -11.202700
# ..                     ...        ...
# 261  Sao Tome and Principe   0.186360
# 262                  Yemen  15.552727
# 263                Comoros -11.645500
# 264             Tajikistan  38.861034
# 265                Lesotho -29.609988
#
# [266 rows x 2 columns]

# %%
infected_data[1:3]
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 1     1385     1416     1464     1521     1590
# 2    10589    10698    10810    10919    11031
#
# [2 rows x 150 columns]

# %%
infected_data['Long']>2.6500
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 261     True
# 262     True
# 263     True
# 264     True
# 265     True
# Name: Long, Length: 266, dtype: bool

# %%
infected_data.loc[infected_data['Long']>2.6500]
# Out:
#                    Province/State         Country/Region        Lat  \
# 0                             NaN            Afghanistan  33.000000
# 1                             NaN                Albania  41.153300
# 4                             NaN                 Angola -11.202700
# 7                             NaN                Armenia  40.069100
# 8    Australian Capital Territory              Australia -35.473500
# ..                            ...                    ...        ...
# 261                           NaN  Sao Tome and Principe   0.186360
# 262                           NaN                  Yemen  15.552727
# 263                           NaN                Comoros -11.645500
# 264                           NaN             Tajikistan  38.861034
# 265                           NaN                Lesotho -29.609988
#
#            Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
recovered_data.name="Recovered People"

# %%
recovered_data
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
# 252            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
recovered_data.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 6/11/20             int64
# 6/12/20             int64
# 6/13/20             int64
# 6/14/20             int64
# 6/15/20             int64
# Length: 150, dtype: object

# %%
recovered_data.index
# Out:
# RangeIndex(start=0, stop=253, step=1)

# %%
recovered_data.iloc[3]
# Out:
# Province/State        NaN
# Country/Region    Andorra
# Lat               42.5063
# Long               1.5218
# 1/22/20                 0
#                    ...
# 6/11/20               780
# 6/12/20               781
# 6/13/20               781
# 6/14/20               781
# 6/15/20               789
# Name: 3, Length: 150, dtype: object

# %%
recovered_data['Long'].mean()
# Out:
# 28.16822271146245

# %%
recovered_data['Lat'].std()
# Out:
# 24.55860202369547

# %%
deaths_data
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
deaths_data["Long"].mean()
# Out:
# 22.538640082706767

# %%
grup_veri=deaths_data.groupby('Country/Region')['6/6/20'].mean()
print(grup_veri)
# Out:
# Country/Region
# Afghanistan           327.0
# Albania                34.0
# Algeria               698.0
# Andorra                51.0
# Angola                  4.0
#                       ...
# West Bank and Gaza      3.0
# Western Sahara          1.0
# Yemen                 111.0
# Zambia                  7.0
# Zimbabwe                4.0
# Name: 6/6/20, Length: 188, dtype: float64

# %%
deaths_data.tail(3) #Son verileri almak için
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 263            NaN        Comoros -11.645500  43.333300        0        0
# 264            NaN     Tajikistan  38.861034  71.276093        0        0
# 265            NaN        Lesotho -29.609988  28.233608        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# 263        0        0        0        0  ...       2       2       2       2
# 264        0        0        0        0  ...      48      48      48      48
# 265        0        0        0        0  ...       0       0       0       0
#
#      6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 263        2        2        2        2        2        2
# 264       48       49       49       50       50       50
# 265        0        0        0        0        0        0
#
# [3 rows x 150 columns]

# %%
deaths_data.gt(recovered_data) #Karşılaştırma
# Out:
#      Province/State  Country/Region    Lat   Long  1/22/20  1/23/20  1/24/20  \
# 0             False           False  False  False    False    False    False
# 1             False           False  False  False    False    False    False
# 2             False           False  False  False    False    False    False
# 3             False           False  False  False    False    False    False
# 4             False           False  False  False    False    False    False
# ..              ...             ...    ...    ...      ...      ...      ...
# 261           False           False  False  False    False    False    False
# 262           False           False  False  False    False    False    False
# 263           False           False  False  False    False    False    False
# 264           False           False  False  False    False    False    False
# 265           False           False  False  False    False    False    False
#
# ...

# %%
def extract_Country(deaths_data):
    deaths_data["Country/Reigon"]
    return deaths_data
deaths_data
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
recovered_data
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
# 252            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
print(recovered_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 296.6+ KB
# None

# %%
print(recovered_data.isnull().sum()) #Her sütundaki eksik değerlerin sayısını gösterir
# Out:
# Province/State    186
# Country/Region      0
# Lat                 0
# Long                0
# 1/22/20             0
#                  ...
# 6/11/20             0
# 6/12/20             0
# 6/13/20             0
# 6/14/20             0
# 6/15/20             0
# Length: 150, dtype: int64

# %%
without_na=recovered_data.dropna() # Eksik değerleri içeren satırları kaldırır

# %%
import numpy as nm
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 2
#       1 import numpy as nm
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df_infected.loc['China'][2:].plot()

#Sadece numerik data'da
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_infected.loc['China'][2:].plot()
#       3 #Sadece numerik data'da
#
# File c:\Users\sevgi\miniconda3\Lib\site-packages\pandas\plotting\_core.py:951, in PlotAccessor.__call__(self, *args, **kwargs)
#     950 def __call__(self, *args, **kwargs):
# --> 951     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     953     x, y, kind, kwargs = self._get_call_args(
#     954         plot_backend.__name__, self._parent, args, kwargs
#     955     )
#     957     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\sevgi\miniconda3\Lib\site-packages\pandas\plotting\_core.py:1947, in _get_plot_backend(backend)
#    1944 if backend_str in _backends:
#    1945     return _backends[backend_str]
# -> 1947 module = _load_backend(backend_str)
#    1948 _backends[backend_str] = module
# ...

# %%
df_infected.drop(columns=['Lat','Long','Province/State'],inplace=True)

# %%
df_infected.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/6/20  6/7/20  6/8/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    1830    1875    2171
# Albania               0        0        0  ...     925     938     945
# Algeria               0        0        0  ...    6631    6717    6799
# Andorra               0        0        0  ...     741     744     751
# Angola                0        0        0  ...      24      24      38
#
# ...

# %%
df_deaths=df_deaths.drop(columns=['Lat','Long','Province/State'])

# %%
df_deaths.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/6/20  6/7/20  6/8/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     327     357     369
# Albania               0        0        0  ...      34      34      34
# Algeria               0        0        0  ...     698     707     715
# Andorra               0        0        0  ...      51      51      51
# Angola                0        0        0  ...       4       4       4
#
# ...

# %%
def make_frame(country:str):
    df=pd.DataFrame({
    'infected_data' :df_infected.loc[country],
    
    'deaths_data' :df_deaths.loc[country]
    })
    df.index=pd.to_datetime(df.index,format='%m/%d/%y')
    return df
    """ Country parametre olarak alıp infected, recovered ve deaths value'leri tarihleri sıralayacak
pd.DataFrame()
    """

    pass

# %%
df_us=make_frame('US')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_us=make_frame('US')
#
# NameError: name 'make_frame' is not defined

# %%
df_us.info()
df_us
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 146 entries, 2020-01-22 to 2020-06-15
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   infected_data  146 non-null    int64
#  1   deaths_data    146 non-null    int64
# dtypes: int64(2)
# memory usage: 3.4 KB
#             infected_data  deaths_data
# 2020-01-22              0            0
# 2020-01-23              0            0
# 2020-01-24              0            0
# 2020-01-25              0            0
# 2020-01-26              0            0
# ...                   ...          ...
# 2020-06-11         540292       113823
# 2020-06-12         547386       114669
# 2020-06-13         556606       115436
# 2020-06-14         561816       115732
# 2020-06-15         576334       116127
#
# [146 rows x 2 columns]

# %%
df_turkey=make_frame
df_turkey
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_turkey=make_frame
#       2 df_turkey
#
# NameError: name 'make_frame' is not defined

# %%
df_us['new_infected'].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_us['new_infected'].plot()
#       2 plt.show()
#
# NameError: name 'df_us' is not defined

# %%
df_us[(df_us.index.year==2020)]['new_infected'].plot()
plt.show()

# %%
df_us[(df_us.index.year==2020) & (df_us.index.month==5)]['new_infected'].plot()
plt.show()

# %%
df_us['new_infected_avg']=df_us['new_infected'].rolling(window=7).mean()

# %%
df_us['new_infected_avg'].plot()

# %% [markdown]
# Burada eksik kısımlar var

# %%
df_us['Rt'].replace(np.inf,np.nan).fillna(method='bfill')

# %%
df_us['Rt'].replace(np.inf,np.nan).bfill()

# %%
rt_array=df_us[df_us.index<'2020-05-01']['Rt'].replace(np.inf,np.nan).bfill()
#Tanımsız olanları nan ile değiştirip içine değer koyma

# %%
print(rt_array)

# %%
rt_array.plot()

plt.show()

# %%
plt.ylim ([0,6])#Limit verme

# %%
df_us.head()
# Out:
#             infected_data  deaths_data
# 2020-01-22              0            0
# 2020-01-23              0            0
# 2020-01-24              0            0
# 2020-01-25              0            0
# 2020-01-26              0            0

# %%
df_us['new_infected'].diff().plot()

# %%
df_us['new_infected'].diff(7).rolling(4).mean().plot

# %% [markdown]
# -See the spread of pandemic in different countries.
# -Plot Rt graphs in different countries side or in the same graph.
# -Check correlation between deaths and recoveries.
# -Are they any outliers(anomalies)?
